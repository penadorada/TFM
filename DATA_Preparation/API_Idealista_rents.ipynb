# %% [markdown]
# ![idealista logo](https://s14-eu5.ixquick.com/cgi-bin/serveimage?url=http%3A%2F%2Ft0.gstatic.com%2Fimages%3Fq%3Dtbn%3AANd9GcQqjeQLlcGYvzPz1B-a2NfDRLNNTjYlpUHJgC-kvYG-jUNehiOA&sp=c82e503b2dd362c5857b2b227c055500&anticache=491873)
#
# ## Goals of this notebook:
# Idealista dataset provides the data about the regular rental market in Madrid.
#     - Retrive all properties for rent listed in idealista.com through the Idealista API.
#     - Visualization of Idealista listings in Madrid map.
#     - Find out average rents in Madrid broken down into neighborhood and appartment size.
#     - Combine Airbnb and Idealista datasets to create a data frame to compare revenues generated in Airbnb and
#       Idealista.

# %%
import numpy as np
import pandas as pd
import requests
import json
from pandas.io.json import json_normalize
import folium

# %% [markdown]
# ## IDEALISTA API

# %%
#  A formal request on the website is necessary to gain acces to their API. 
# Response email by Idealista labs

# Te hemos habilitado el acceso al api (adjuntamos la documentación):

#Apikey: hds4ce6tz7wgnkm7z3pgtsiu0ua1ppq2
#Secret: WvB72IPBDAfn
#Este acceso será gratuito hasta un máximo de 100 peticiones al mes. Si necesitas ampliarlo, puedes contactar con nosotros :)

# %% [markdown]
# -  An access token is required to call the Idealista API. To get the access token we follow the instructions
#    provided by Idealista:
#
#     1) API key and secret must be encoded in Basic 64. To do so: https://www.base64encode.org/
#
#     2) Input-->APIkey:secret (remember to enter colon)
#
#     3) Authorization header: aGRzNGNlNnR6N3dnbmttN3ozcGd0c2l1MHVhMXBwcTI6V3ZCNzJJUEJEQWZu
#
#     4) Get the token: We use terminal rather than notebook to request our token:
#        curl -X POST -H "Authorization: Basic aGRzNGNlNnR6N3dnbmttN3ozcGd0c2l1MHVhMXBwcTI6V3ZCNzJJUEJEQWZu" -H "Content-Type:application/x-www-form-urlencoded" -d 'grant_type=client_credentials&scope=read' 'https://api.idealista.com/oauth/token' -k

# %%
# Once we have our(long) token, we may request the data through the API
# Idealista API returns paginated results. As far as Madrid is concerned, there are 114 pages. 
# Given that we only have 100 calls per month we call the API twice, to make sure it works properly. 
# Imporatant to note in the Readme that airbnb data was downloaded in april 2017 whereas Idealista dataset has been 
# retrieved in October 2017
ideal = []
token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTUwNzA2NjQzMSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiMmNlZDBhM2EtNDM2MC00NGZkLWE1ZjQtMGM3MDIxNWM3N2Y4IiwiY2xpZW50X2lkIjoiaGRzNGNlNnR6N3dnbmttN3ozcGd0c2l1MHVhMXBwcTIifQ.1FNr6xQnvgEK3PKBksfte168E7XumRqTahawb4TM9ZQ'

for page in range(1,60):
    page = str(page)
    url = "http://api.idealista.com/3.5/es/search?country=es&maxItems=50&&sinceDate=M&hasMultimedia=True&propertyType=homes&operation=rent&locationId=0-EU-ES-28&numPage="+page
    headers = {'Authorization' : 'Bearer ' + token}
    content = requests.post(url,headers=headers)
    resp = json.loads(content.content)
    ideal +=[resp]
    
len(ideal)
# Out:
# 55

# %%
ideab = []
token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTUwNzkzNTMzNSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiODY1MTBhMzktZTgzYS00MWUyLWJmN2ItMDQ2M2I3NWQwZDhkIiwiY2xpZW50X2lkIjoiaGRzNGNlNnR6N3dnbmttN3ozcGd0c2l1MHVhMXBwcTIifQ.DGmMlqUK1tF3YINJSW9k7iud9_mJhXFVTppOWzp7IcI"
for page in range(60,112):
    page = str(page)
    url = "http://api.idealista.com/3.5/es/search?country=es&maxItems=50&&sinceDate=M&hasMultimedia=True&propertyType=homes&operation=rent&locationId=0-EU-ES-28&numPage="+page
    headers = {'Authorization' : 'Bearer ' + token}
    content = requests.post(url,headers=headers)
    resp = json.loads(content.content)
    ideab +=[resp]
    
len(ideab)
# Out:
# 52

# %%
idea = json_normalize(ideab, 'elementList')
idea.shape
# Out:
# (2476, 33)

# %%
# Save info in a csv,
idea.to_csv('idealista2.csv',encoding='utf8')

# %%
# Join both csv and create a dataset with all listings of Idealista in Madrid.
# Datasets on github, TFM/datasets folder
idi1 = pd.read_csv('idealista1.csv')
idi2 = pd.read_csv('idealista2.csv')
df = pd.concat([idi1,idi2])
df.shape
# Out:
# (5226, 34)

# %% [markdown]
# ## VISUALIZATION OF RENTAL MARKET OFFER
# #### Idealista listings location in Madrid map

# %%
# Flats for rent in Madrid (red spot)
m = folium.Map(location=[40.421522, -3.6938], zoom_start=10)
for index,row in df.iterrows():
    folium.Circle([row['latitude'], row['longitude']],
                        radius=1,
                        color='crimson',
                        fill=True,
                        fill_color='crimson',
                       ).add_to(m)

m.save('ideal_rents.png')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### IDEALISTA  DATA CLEANING
# - Features selection.
# - NaNs
# - Areas, neighbourhood filtering
# - Outliers, duplicates check

# %%
df.head()
# Out:
#    Unnamed: 0                           address  bathrooms country  \
# 0           0       barrio Ciudad Universitaria          1      es
# 1           1           calle Conde de Duque, 6          1      es
# 2           2    barrio Bernabéu-Hispanoamérica          3      es
# 3           3  calle de la infanta mercedes, 62          1      es
# 4           4                    calle Castelló          2      es
#
#                                         detailedType   district exterior  \
# 0                             {u'typology': u'flat'}    Moncloa     True
# 1  {u'subTypology': u'studio', u'typology': u'flat'}     Centro    False
# 2                             {u'typology': u'flat'}  Chamartín     True
# 3                             {u'typology': u'flat'}     Tetuán    False
# 4                             {u'typology': u'flat'}  Salamanca     True
#
#   externalReference floor has3DTour                ...                  \
# 0             01495     5     False                ...
# 1               NaN     3     False                ...
# 2             01494     3     False                ...
# 3               NaN     3     False                ...
# 4          ACC20817     5     False                ...
#
#   propertyCode propertyType province  rooms  showAddress   size status  \
# 0     38312706         flat   Madrid      2        False  100.0   good
# 1     38312999       studio   Madrid      0         True   25.0   good
# 2     38302487         flat   Madrid      4        False  180.0   good
# 3     33858989         flat   Madrid      1         True   40.0   good
# 4     38312846         flat   Madrid      2        False  120.0   good
#
#                                       suggestedTexts  \
# 0  {u'subtitle': u'Ciudad Universitaria, Madrid',...
# 1  {u'subtitle': u'Malasaña-Universidad, Madrid',...
# 2  {u'subtitle': u'Bernabéu-Hispanoamérica, Madri...
# 3  {u'subtitle': u'Cuzco-Castillejos, Madrid', u'...
# 4  {u'subtitle': u'Castellana, Madrid', u'title':...
#
#                                            thumbnail  \
# 0  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#                                  url
# 0  http://www.idealista.com/38312706
# 1  http://www.idealista.com/38312999
# 2  http://www.idealista.com/38302487
# 3  http://www.idealista.com/33858989
# 4  http://www.idealista.com/38312846
#
# [5 rows x 34 columns]

# %%
# Explore Idealista dataset. Variables of interest
df[['address','district','neighborhood','size','rooms','price','priceByArea','floor']]
# Out:
#                                         address  \
# 0                   barrio Ciudad Universitaria
# 1                       calle Conde de Duque, 6
# 2                barrio Bernabéu-Hispanoamérica
# 3              calle de la infanta mercedes, 62
# 4                                calle Castelló
# 5                        barrio Chueca-Justicia
# 6                        paseo de la Castellana
# 7                  calle Bernardino Obregón, 19
# 8                                        Centro
# 9                                barrio El Viso
# 10                          principe de Vergara
# 11      plaza del conde del valle de súchil s/n
# 12                   calle de bravo murillo, 36
# 13                      barrio Fuente del Berro
# 14                             barrio Argüelles
# 15                         calle Claudio Coello
# 16                    calle de Cristóbal Bordiú
# 17                                   carniceria
# 18                                 c. norte, 20
# 19                                calle Velayos
# 20          calle San Esteban Ur Cantagallo, 12
# 21                                   calle Jaén
# 22                           san Vicente Ferrer
# 23                        calle de San Pedro, 3
# 24    avenida del Monasterio de El Escorial, 73
# 25                           calle Colombia, 53
# 26                    vicente Blasco Ibañez, 15
# 27                              calle MAGDALENA
# 28                    avenida de la Pedriza, 13
# 29                            camino de la raya
# ...                                         ...
# 2446                     El Soto de la Moraleja
# 2447                            barrio Castilla
# 2448                            barrio Arapiles
# 2449                             barrio Adelfas
# 2450                             barrio Adelfas
# 2451                                    Colonia
# 2452                  barrio Parque Empresarial
# 2453                                La Canaleja
# 2454             Raya del Palancar - Guadamonte
# 2455                               barrio Timón
# 2456                             barrio Adelfas
# 2457                 barrio Zona Avenida Europa
# 2458                            barrio Castilla
# 2459                            barrio Castilla
# 2460                           barrio San Diego
# 2461                        barrio Nueva España
# 2462                    barrio Alameda de Osuna
# 2463                   barrio Palomeras sureste
# 2464                                 Los Robles
# 2465                         barrio Sanchinarro
# 2466                          barrio Concepción
# 2467                                  Ciudad 70
# 2468                          barrio Niño Jesús
# 2469                       barrio Ciudad Jardín
# 2470                               Navalcarnero
# 2471                           barrio Trafalgar
# 2472                                     Centro
# 2473                       barrio Ciudad Jardín
# 2474                           barrio Trafalgar
# 2475                  calle de Palas de Rey, 48
#
#                             district                   neighborhood    size  \
# 0                            Moncloa           Ciudad Universitaria   100.0
# 1                             Centro           Malasaña-Universidad    25.0
# 2                          Chamartín        Bernabéu-Hispanoamérica   180.0
# 3                             Tetuán              Cuzco-Castillejos    40.0
# 4                          Salamanca                     Castellana   120.0
# 5                             Centro                Chueca-Justicia    93.0
# 6                             Tetuán                 Cuatro Caminos    90.0
# 7                         Arganzuela                Palos de Moguer    50.0
# 8                             Centro                            NaN    70.0
# 9                          Chamartín                        El Viso    95.0
# 10                         Chamartín        Bernabéu-Hispanoamérica    70.0
# 11                          Chamberí                       Arapiles   160.0
# 12                          Chamberí                      Trafalgar   133.0
# 13                         Salamanca               Fuente del Berro    90.0
# 14                           Moncloa                      Argüelles   127.0
# 15                         Salamanca                      Recoletos    60.0
# 16                          Chamberí  Nuevos Ministerios-Ríos Rosas    90.0
# 17                               NaN                            NaN   140.0
# 18                               NaN                            NaN   195.0
# 19                           Moncloa           Ciudad Universitaria   190.0
# 20                               NaN                            NaN   320.0
# 21                            Tetuán                 Cuatro Caminos    40.0
# 22                            Centro           Malasaña-Universidad    65.0
# 23                               NaN                            NaN    90.0
# 24                        Fuencarral                   Montecarmelo    98.0
# 25                         Chamartín        Bernabéu-Hispanoamérica    65.0
# 26                         Hortaleza                    Sanchinarro   130.0
# 27                            Centro           Lavapiés-Embajadores    53.0
# 28                               NaN                            NaN    85.0
# 29    Raya del Palancar - Guadamonte                            NaN   105.0
# ...                              ...                            ...     ...
# 2446          El Soto de la Moraleja                            NaN   373.0
# 2447                       Chamartín                       Castilla    68.0
# 2448                        Chamberí                       Arapiles    95.0
# 2449                          Retiro                        Adelfas   120.0
# 2450                          Retiro                        Adelfas   120.0
# 2451                         Colonia                            NaN    70.0
# 2452              Parque Empresarial             Parque Empresarial   130.0
# 2453                     La Canaleja                            NaN   265.0
# 2454  Raya del Palancar - Guadamonte                            NaN    60.0
# 2455                         Barajas                          Timón   140.0
# 2456                          Retiro                        Adelfas   120.0
# 2457             Zona Avenida Europa            Zona Avenida Europa   150.0
# 2458                       Chamartín                       Castilla    52.0
# 2459                       Chamartín                       Castilla    70.0
# 2460              Puente de Vallecas                      San Diego    70.0
# 2461                       Chamartín                   Nueva España    41.0
# 2462                         Barajas               Alameda de Osuna    90.0
# 2463              Puente de Vallecas              Palomeras sureste    27.0
# 2464                      Los Robles                            NaN  1000.0
# 2465                       Hortaleza                    Sanchinarro   105.0
# 2466                   Ciudad Lineal                     Concepción    67.0
# 2467                       Ciudad 70                            NaN    95.0
# 2468                          Retiro                     Niño Jesús   120.0
# 2469                       Chamartín                  Ciudad Jardín    50.0
# 2470                             NaN                            NaN   135.0
# 2471                        Chamberí                      Trafalgar   165.0
# 2472                          Centro                            NaN    70.0
# 2473                       Chamartín                  Ciudad Jardín    65.0
# 2474                        Chamberí                      Trafalgar   150.0
# 2475                      Fuencarral                     Las Tablas   101.0
#
#       rooms   price  priceByArea floor
# 0         2  1600.0         16.0     5
# 1         0   800.0         32.0     3
# 2         4  2400.0         13.0     3
# 3         1   950.0         24.0     3
# 4         2  2250.0         19.0     5
# 5         1  1500.0         16.0     1
# 6         2  1500.0         17.0     7
# 7         1   875.0         18.0     2
# 8         2   650.0          9.0     1
# 9         2  2500.0         26.0     2
# 10        2  1380.0         20.0     1
# 11        4  1950.0         12.0     6
# 12        4  1900.0         14.0     6
# 13        2  1200.0         13.0     2
# 14        4  2800.0         22.0     6
# 15        1  1150.0         19.0     4
# 16        3  1300.0         14.0     6
# 17        3   700.0          5.0     2
# 18        3  1000.0          5.0   NaN
# 19        5  2100.0         11.0     2
# 20        4  1500.0          5.0   NaN
# 21        1   720.0         18.0     3
# 22        2   990.0         15.0     3
# 23        2   450.0          5.0   NaN
# 24        2  1300.0         13.0     1
# 25        2  1100.0         17.0     2
# 26        3  1300.0         10.0     1
# 27        1   950.0         18.0     1
# 28        2   560.0          7.0    bj
# 29        3   950.0          9.0   NaN
# ...     ...     ...          ...   ...
# 2446      4  4700.0         13.0   NaN
# 2447      1   950.0         14.0     9
# 2448      2  1300.0         14.0    bj
# 2449      3  1400.0         12.0     1
# 2450      3  1400.0         12.0     1
# 2451      2   695.0         10.0     2
# 2452      4  1400.0         11.0     3
# 2453      4   980.0          4.0   NaN
# 2454      0   650.0         11.0    ss
# 2455      3  1200.0          9.0     4
# 2456      3  1400.0         12.0     2
# 2457      4  1500.0         10.0     2
# 2458      1   950.0         18.0     9
# 2459      1  1050.0         15.0     4
# 2460      2   680.0         10.0     2
# 2461      1   700.0         17.0     4
# 2462      2  1100.0         12.0     3
# 2463      1   465.0         17.0   NaN
# 2464      5  4000.0          4.0   NaN
# 2465      3  1350.0         13.0     2
# 2466      2   950.0         14.0     3
# 2467      3   600.0          6.0     1
# 2468      3  1400.0         12.0     1
# 2469      1   720.0         14.0     2
# 2470      3   650.0          5.0   NaN
# 2471      3  2200.0         13.0     7
# 2472      2   650.0          9.0     5
# 2473      1   950.0         15.0     1
# 2474      3  2790.0         19.0     5
# 2475      2  1200.0         12.0     1
#
# [5226 rows x 8 columns]

# %%
# We get rid of rows with no neighbourhood. As seen above, these are listings of small towns near Madrid city
df = df.drop(df[df.district.isnull()].index)
df.shape
# Out:
# (4702, 34)

# %%
# Duplicated listings check
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### DISTRICT SELECTION
# - Idealista API information includes properties located outside the metropolitan area of Madrid. We remove them.
# - In order to compare properties we need to have the same districts in the idealista dataset and the airbnb one.

# %%
df.district.value_counts()
# Out:
# Salamanca                                455
# Centro                                   358
# Chamartín                                301
# Chamberí                                 269
# Tetuán                                   256
# Fuencarral                               198
# Moncloa                                  191
# Hortaleza                                181
# Retiro                                   127
# Ciudad Lineal                            112
# Arganzuela                               102
# Carabanchel                               96
# San Blas                                  89
# Puente de Vallecas                        78
# Latina                                    52
# Usera                                     49
# Barajas                                   44
# Villa de Vallecas                         43
# Zona Prado de Somosaguas - La Finca       40
# Villaverde                                36
# Moratalaz                                 25
# Rozas Centro                              23
# Vicálvaro                                 20
# Urbanizaciones                            18
# Somosaguas                                18
# Zona Avenida Europa                       16
# El Cantizal                               11
# El Burgo                                  10
# Molino de la Hoz                           9
# Zona Pueblo                                9
# El Pinar- Punta Galea                      9
# Las Matas- Peñascales                      8
# Zona Estación                              7
# Parque Empresarial                         5
# Marazuela- El Torreón                      4
# Zona norte                                 4
# Valderas - Los Castillos                   4
# Monte Rozas                                4
# Zarzaquemada                               4
# Campodón - Ventorro del Cano               3
# Parque Ondarreta - Urtinsa                 3
# San Nicasio - Campo de Tiro - Solagua      3
# Yucatán- Las Cornisas                      3
# Europolis                                  3
# La Fortuna                                 2
# Parque Lisboa - La Paz                     2
# Parque oeste - Fuente Cisneros             2
# Montecillo - Pinar de las Rozas            1
# Club de Golf                               1
# Name: district, dtype: int64

# %%
# Selection of properties located in Madrid districts
areas = ['Centro',u'Arganzuela',u'Retiro',u'Salamanca','Chamartín','Moratalaz','Tetuán','Chamberí','Fuerncarral','El Pardo','Moncloa','Aravaca',
        'Carabanchel','Latina','Puente de Vallecas','Usera','Ciudad Lineal','Hortaleza','Villaverde','Villa de Vallecas','Vicálvaro','San Blas','Canillejas','Barajas']
df = df[df.district.isin(areas)]
df.shape
# Out:
# (3461, 34)

# %%
# We remove rows with missing neighbourhood. After checking manually we realise these properties are in the suburbs.
df.drop(df[df.neighborhood.isnull()].index)
df.shape
# Out:
# (3461, 34)

# %%
# Outliers check (prices over 10000)
# Looks fine
df.groupby(['neighborhood','rooms'],as_index=False).price.max().sort_values(by='price',ascending=False)

# %%
# Group by neighbourhood, rooms and price.
# Again, we use the median instead of the mean to have a more accurate measure of average rents
ide = df.groupby(['neighborhood','rooms'],as_index=False).price.agg(['median','count']).reset_index()
ide = pd.DataFrame(ide)
ide
# Out:
#                        neighborhood  rooms  median  count
# 0             12 de Octubre-Orcasur      0   600.0      1
# 1             12 de Octubre-Orcasur      1   575.0      1
# 2             12 de Octubre-Orcasur      2   810.0      1
# 3             12 de Octubre-Orcasur      3   950.0      2
# 4                          Abrantes      2   650.0      4
# 5                          Abrantes      3   750.0      3
# 6                          Abrantes      4  1000.0      4
# 7                           Acacias      0   475.0      1
# 8                           Acacias      1   825.0      6
# 9                           Acacias      2  1012.5      4
# 10                          Acacias      3  1300.0     10
# 11                          Acacias      4  1350.0      1
# 12                          Adelfas      1   975.0      5
# 13                          Adelfas      2  1200.0     11
# 14                          Adelfas      3  1400.0     13
# 15                          Adelfas      4  1650.0      1
# 16                       Aeropuerto      2   650.0      1
# 17                 Alameda de Osuna      1   899.0      2
# 18                 Alameda de Osuna      2  1100.0      9
# 19                 Alameda de Osuna      3  1245.0      6
# 20                          Almagro      0   900.0      2
# 21                          Almagro      1  1200.0     10
# 22                          Almagro      2  2350.0     27
# 23                          Almagro      3  2475.0     16
# 24                          Almagro      4  2675.0      8
# 25                          Almagro      5  5500.0      4
# 26                      Almendrales      0   660.0      7
# 27                      Almendrales      1   880.0      1
# 28                      Almendrales      2   750.0      2
# 29                           Aluche      2   660.0      5
# ..                              ...    ...     ...    ...
# 467                    Vallehermoso      5  3000.0      4
# 468                          Ventas      0   800.0      1
# 469                          Ventas      1   700.0      4
# 470                          Ventas      2   800.0      5
# 471                          Ventas      3   800.0      7
# 472               Ventilla-Almenara      0   745.0      3
# 473               Ventilla-Almenara      1  1000.0      7
# 474               Ventilla-Almenara      2  1250.0     15
# 475               Ventilla-Almenara      3  1450.0      3
# 476               Ventilla-Almenara      4  1850.0      3
# 477               Ventilla-Almenara      5  2500.0      1
# 478                       Vinateros      2   850.0      1
# 479                       Vinateros      3   887.5      2
# 480  Virgen del Cortijo - Manoteras      0   840.0      3
# 481  Virgen del Cortijo - Manoteras      1   900.0      6
# 482  Virgen del Cortijo - Manoteras      2  1287.5      4
# 483  Virgen del Cortijo - Manoteras      3   850.0      1
# 484                    Vista Alegre      1   725.0      4
# 485                    Vista Alegre      2   700.0      7
# 486                    Vista Alegre      3   800.0      9
# 487                    Vista Alegre      4   800.0      1
# 488                        Vírgenes      3   700.0      1
# 489                           Zofío      2   575.0      4
# 490                           Zofío      3   780.0      1
# 491               Zona Centro Joven      3   600.0      1
# 492                      Zona Renfe      1   620.0      2
# 493                      Zona Renfe      2   600.0      1
# 494                      Zona Renfe      3   625.0      2
# 495                         Águilas      2   650.0      6
# 496                         Águilas      3   700.0      2
#
# [497 rows x 4 columns]

# %%
# Several 'barrios' in idealista have different names than Airbnb, so before carry on, we have to amend those names in order
# to have neighborhoods properly classified 

ide['neighborhood']=ide.neighborhood.str.replace('Conde Orgaz-Piovera','Piovera')
ide['neighborhood']=ide.neighborhood.str.replace('Bernabéu-Hispanoamérica','Hispanoamérica')
ide['neighborhood']=ide.neighborhood.str.replace('Cuzco-Castillejos','Castillejos')
ide['neighborhood']=ide.neighborhood.str.replace('Chueca-Justicia','Justicia')
ide['neighborhood']=ide.neighborhood.str.replace('Lavapiés-Embajadores','Embajadores')
ide['neighborhood']=ide.neighborhood.str.replace('Huertas-Cortes','Cortes')
ide['neighborhood']=ide.neighborhood.str.replace('Valdebebas - Valdefuentes','Valdefuentes')
ide['neighborhood']=ide.neighborhood.str.replace('Nuevos Ministerios-Ríos Rosas','Rios Rosas')
ide['neighborhood']=ide.neighborhood.str.replace('Malasaña-Universidad','Universidad')
ide['neighborhood']=ide.neighborhood.str.replace('Ventilla-Almenara','Almenara')
ide['neighborhood']=ide.neighborhood.str.replace('Sanchinarro','Valdefuentes')

# %% [markdown]
# ### 1) AIRBNB Dataset preparation

# %%
# First we import airbnb dataset and create a dataframe with the same variables than idealista`s table.
bnb = pd.read_csv('airbnb1.csv')
bnb.shape
# Out:
# (10073, 100)

# %%
bnb.room_type.value_counts()
# Out:
# Entire home/apt    6269
# Private room       3643
# Shared room         161
# Name: room_type, dtype: int64

# %%
# Shared rooms and Private rooms are ignored. Focus on flats
# We remove Private room and Shared room category
bnb = bnb.drop(bnb[(bnb.room_type=='Private room') | (bnb.room_type=='Shared room')].index)
bnb.shape
# Out:
# (6269, 100)

# %%
# Selection of variables of interest
bnb1 = bnb[['neighbourhood_group_cleansed','neighbourhood_cleansed','bedrooms','accommodates','price','availability_30']]

# %%
bnb1[bnb1.neighbourhood_cleansed=='Atocha']
# Out:
#      neighbourhood_group_cleansed neighbourhood_cleansed  bedrooms  \
# 5848                   Arganzuela                 Atocha       1.0
# 5849                   Arganzuela                 Atocha       2.0
# 5850                   Arganzuela                 Atocha       3.0
# 5851                   Arganzuela                 Atocha       1.0
# 5853                   Arganzuela                 Atocha       1.0
# 5854                   Arganzuela                 Atocha       4.0
# 5855                   Arganzuela                 Atocha       1.0
# 5856                   Arganzuela                 Atocha       1.0
# 5859                   Arganzuela                 Atocha       1.0
#
#       accommodates     price  availability_30
# 5848             2   84.1429                3
# 5849             6   73.4919                4
# 5850             7   89.4684               11
# 5851             3   52.1899                1
# 5853             3   52.1899                0
# 5854            10  143.7885               14
# 5855             4   52.1899                0
# 5856             2   74.5570                7
# 5859             2   62.8409                7

# %%
# Deduction  of avg price, number of flats and occupancy in each neighbourhood
bnb2 = bnb1.groupby(['neighbourhood_cleansed','bedrooms'],as_index=False).price.agg(['median','count']).reset_index()
bnb3 = bnb1.groupby(['neighbourhood_cleansed','bedrooms'],as_index=False).availability_30.mean()

# %%
# Merge bnb2 and bnb3
bnbs = [bnb2,bnb3]
bnb4 = reduce(lambda left,right: pd.merge(left,right,on=['neighbourhood_cleansed','bedrooms']),bnbs)
bnb4
# Out:
#     neighbourhood_cleansed  bedrooms     median  count  availability_30
# 0                 Abrantes       1.0   53.25500      1         9.000000
# 1                 Abrantes       2.0   56.45030      1        13.000000
# 2                  Acacias       0.0   36.74595      4        14.500000
# 3                  Acacias       1.0   63.90600     21         7.571429
# 4                  Acacias       2.0   83.61035     18         8.666667
# 5                  Acacias       3.0   63.90600      1        13.000000
# 6                  Acacias       4.0  117.16100      1         2.000000
# 7                  Adelfas       0.0   53.25500      4         5.000000
# 8                  Adelfas       1.0   69.23150     10        11.800000
# 9                  Adelfas       2.0   83.07780      9         9.111111
# 10                 Adelfas       3.0  150.17910      1        10.000000
# 11                 Adelfas       4.0  106.51000      1        14.000000
# 12              Aeropuerto       1.0   42.60400      1        12.000000
# 13                 Aguilas       2.0   58.04795      2        10.500000
# 14        Alameda de Osuna       2.0   87.87075      2        10.000000
# 15                 Almagro       0.0   69.23150      9        10.000000
# 16                 Almagro       1.0   80.94760     34         8.911765
# 17                 Almagro       2.0  106.51000     21         9.809524
# 18                 Almagro       3.0  176.80660      5        12.000000
# 19                 Almagro       4.0  244.97300      1         8.000000
# 20                Almenara       0.0   53.25500      5         8.800000
# 21                Almenara       1.0   68.69895      4         9.750000
# 22                Almenara       2.0   83.07780      3        10.333333
# 23                Almenara       3.0  117.16100      2         8.500000
# 24             Almendrales       0.0   34.08320      5         7.000000
# 25             Almendrales       1.0   42.60400      3        12.333333
# 26             Almendrales       3.0  232.72435      2        15.000000
# 27                  Aluche       2.0   71.89425      2         8.000000
# 28                  Aluche       3.0   58.58050      3         7.333333
# 29        Apostol Santiago       0.0   79.88250      1        24.000000
# ..                     ...       ...        ...    ...              ...
# 390          Valdeacederas       1.0   53.25500     10        13.000000
# 391          Valdeacederas       2.0   82.54525      6        18.000000
# 392          Valdeacederas       3.0  234.32200      1         4.000000
# 393           Valdefuentes       0.0   47.92950      2        11.000000
# 394           Valdefuentes       1.0   64.97110      6         9.833333
# 395           Valdefuentes       2.0   85.20800      3        17.000000
# 396           Valdefuentes       3.0  105.44490      4        15.500000
# 397           Valdefuentes       4.0  127.81200      1        17.000000
# 398           Valdefuentes       5.0  138.46300      1        14.000000
# 399             Valdezarza       1.0   53.25500      1         1.000000
# 400             Valdezarza       2.0   53.25500      1         5.000000
# 401           Vallehermoso       0.0   55.91775      2         3.500000
# 402           Vallehermoso       1.0   63.90600     13        20.076923
# 403           Vallehermoso       2.0  138.46300      7        15.714286
# 404           Vallehermoso       3.0   82.54525      2         7.500000
# 405               Valverde       1.0   94.26135      4        15.500000
# 406               Valverde       2.0   71.89425      4        15.250000
# 407               Valverde       3.0  103.84725      2         6.500000
# 408                 Ventas       1.0   52.18990      6         7.333333
# 409                 Ventas       2.0   52.72245     10        10.900000
# 410                 Ventas       3.0   53.25500      3         9.333333
# 411                 Ventas       4.0   47.92950      1         6.000000
# 412              Vinateros       2.0   69.23150      1        13.000000
# 413              Vinateros       4.0  149.11400      1         9.000000
# 414           Vista Alegre       1.0   36.74595      4        12.750000
# 415           Vista Alegre       2.0   50.59225      2        17.000000
# 416           Vista Alegre       3.0   80.41505      2        15.000000
# 417           Vista Alegre       5.0  360.00380      1         9.000000
# 418                  Zofío       2.0   61.24325      2        12.000000
# 419                  Zofío       4.0   55.38520      1        13.000000
#
# [420 rows x 5 columns]

# %%
# Addition of new variable: gross estimated income 
# Summary df with estimated income for each neighbourhood and apartment size
bnb4.rename(columns={'median':'Avg_Price_Night_Airbnb','neighbourhood_cleansed':'neighborhood','bedrooms':'rooms'},inplace=True)
bnb4['Estimated_income_Airbnb_EUR'] = bnb4.Avg_Price_Night_Airbnb*(30 - bnb4.availability_30)
bnb4
# Out:
#          neighborhood  rooms  Avg_Price_Night_Airbnb  count  availability_30  \
# 0            Abrantes    1.0                53.25500      1         9.000000
# 1            Abrantes    2.0                56.45030      1        13.000000
# 2             Acacias    0.0                36.74595      4        14.500000
# 3             Acacias    1.0                63.90600     21         7.571429
# 4             Acacias    2.0                83.61035     18         8.666667
# 5             Acacias    3.0                63.90600      1        13.000000
# 6             Acacias    4.0               117.16100      1         2.000000
# 7             Adelfas    0.0                53.25500      4         5.000000
# 8             Adelfas    1.0                69.23150     10        11.800000
# 9             Adelfas    2.0                83.07780      9         9.111111
# 10            Adelfas    3.0               150.17910      1        10.000000
# 11            Adelfas    4.0               106.51000      1        14.000000
# 12         Aeropuerto    1.0                42.60400      1        12.000000
# 13            Aguilas    2.0                58.04795      2        10.500000
# 14   Alameda de Osuna    2.0                87.87075      2        10.000000
# 15            Almagro    0.0                69.23150      9        10.000000
# 16            Almagro    1.0                80.94760     34         8.911765
# 17            Almagro    2.0               106.51000     21         9.809524
# 18            Almagro    3.0               176.80660      5        12.000000
# 19            Almagro    4.0               244.97300      1         8.000000
# 20           Almenara    0.0                53.25500      5         8.800000
# 21           Almenara    1.0                68.69895      4         9.750000
# 22           Almenara    2.0                83.07780      3        10.333333
# 23           Almenara    3.0               117.16100      2         8.500000
# 24        Almendrales    0.0                34.08320      5         7.000000
# 25        Almendrales    1.0                42.60400      3        12.333333
# 26        Almendrales    3.0               232.72435      2        15.000000
# 27             Aluche    2.0                71.89425      2         8.000000
# 28             Aluche    3.0                58.58050      3         7.333333
# 29   Apostol Santiago    0.0                79.88250      1        24.000000
# ..                ...    ...                     ...    ...              ...
# 390     Valdeacederas    1.0                53.25500     10        13.000000
# 391     Valdeacederas    2.0                82.54525      6        18.000000
# 392     Valdeacederas    3.0               234.32200      1         4.000000
# 393      Valdefuentes    0.0                47.92950      2        11.000000
# 394      Valdefuentes    1.0                64.97110      6         9.833333
# 395      Valdefuentes    2.0                85.20800      3        17.000000
# 396      Valdefuentes    3.0               105.44490      4        15.500000
# 397      Valdefuentes    4.0               127.81200      1        17.000000
# 398      Valdefuentes    5.0               138.46300      1        14.000000
# 399        Valdezarza    1.0                53.25500      1         1.000000
# 400        Valdezarza    2.0                53.25500      1         5.000000
# 401      Vallehermoso    0.0                55.91775      2         3.500000
# 402      Vallehermoso    1.0                63.90600     13        20.076923
# 403      Vallehermoso    2.0               138.46300      7        15.714286
# 404      Vallehermoso    3.0                82.54525      2         7.500000
# 405          Valverde    1.0                94.26135      4        15.500000
# 406          Valverde    2.0                71.89425      4        15.250000
# 407          Valverde    3.0               103.84725      2         6.500000
# 408            Ventas    1.0                52.18990      6         7.333333
# 409            Ventas    2.0                52.72245     10        10.900000
# 410            Ventas    3.0                53.25500      3         9.333333
# 411            Ventas    4.0                47.92950      1         6.000000
# 412         Vinateros    2.0                69.23150      1        13.000000
# 413         Vinateros    4.0               149.11400      1         9.000000
# 414      Vista Alegre    1.0                36.74595      4        12.750000
# 415      Vista Alegre    2.0                50.59225      2        17.000000
# 416      Vista Alegre    3.0                80.41505      2        15.000000
# 417      Vista Alegre    5.0               360.00380      1         9.000000
# 418             Zofío    2.0                61.24325      2        12.000000
# 419             Zofío    4.0                55.38520      1        13.000000
#
#      Estimated_income_Airbnb_EUR
# 0                    1118.355000
# 1                     959.655100
# 2                     569.562225
# 3                    1433.320286
# 4                    1783.687467
# 5                    1086.402000
# 6                    3280.508000
# 7                    1331.375000
# 8                    1260.013300
# 9                    1735.402933
# 10                   3003.582000
# 11                   1704.160000
# 12                    766.872000
# 13                   1131.935025
# 14                   1757.415000
# 15                   1384.630000
# 16                   1707.042035
# 17                   2150.487619
# 18                   3182.518800
# 19                   5389.406000
# 20                   1129.006000
# 21                   1391.153738
# 22                   1633.863400
# 23                   2518.961500
# 24                    783.913600
# 25                    752.670667
# 26                   3490.865250
# 27                   1581.673500
# 28                   1327.824667
# 29                    479.295000
# ..                           ...
# 390                   905.335000
# 391                   990.543000
# 392                  6092.372000
# 393                   910.660500
# 394                  1310.250517
# 395                  1107.704000
# 396                  1528.951050
# 397                  1661.556000
# 398                  2215.408000
# 399                  1544.395000
# 400                  1331.375000
# 401                  1481.820375
# 402                   634.144154
# 403                  1978.042857
# 404                  1857.268125
# 405                  1366.789575
# 406                  1060.440188
# 407                  2440.410375
# 408                  1182.971067
# 409                  1006.998795
# 410                  1100.603333
# 411                  1150.308000
# 412                  1176.935500
# 413                  3131.394000
# 414                   633.867638
# 415                   657.699250
# 416                  1206.225750
# 417                  7560.079800
# 418                  1102.378500
# 419                   941.548400
#
# [420 rows x 6 columns]

# %% [markdown]
# ### 3) Merge both datasets to get final summary dataframe

# %%
# In order to compare incomes, we create a single data frame with income estimations of both types of rentals.

fin = pd.merge(ide,bnb4,how='outer',on=['neighborhood','rooms'])

# %%
# Rename columns
fin.rename(columns={'median':'Monthly_rent_Idealista_EUR','count_x':'Number_flats_IDEALISTA','count_y':'Number_flats_AIRBNB'},inplace=True)

# %%
# Neighborhoods with no airbnb listings are deleted
afueras = ['Zona Renfe','Virgen del Cortijo - Manoteras','12 de Octubre-Orcasur','Ambroz','Atalaya','Campo de las Naciones-Corralejos',
          'Casco Antiguo','El Cañaveral - Los Berrocales','Descubridores-Escritores','Ensanche de Vallecas - La Gavia','Los Ángeles',
          'Orcasitas','Pau de Carabanchel','Valdebernardo - Valderribas','Valdemarín']
fin = fin.drop(fin[fin.neighborhood.isin(afueras)].index)

# %%
# NaNs 
# Missing values means no offer available so NaNs replaced by 0.
fin = fin.replace(np.nan,0)

# %%
# NEW COLUMNS:
# Difference of income: premia over regular rent received if flat rented on Airbnb
fin['Holyday_rental_premium_pct'] = ((fin.Estimated_income_Airbnb_EUR - fin.Monthly_rent_Idealista_EUR)/fin.Monthly_rent_Idealista_EUR)*100

fin.head()
# Out:
#   neighborhood  rooms  Monthly_rent_Idealista_EUR  Number_flats_IDEALISTA  \
# 4     Abrantes      2                       650.0                     4.0
# 5     Abrantes      3                       750.0                     3.0
# 6     Abrantes      4                      1000.0                     4.0
# 7      Acacias      0                       475.0                     1.0
# 8      Acacias      1                       825.0                     6.0
#
#    Avg_Price_Night_Airbnb  Number_flats_AIRBNB  availability_30  \
# 4                56.45030                  1.0        13.000000
# 5                 0.00000                  0.0         0.000000
# 6                 0.00000                  0.0         0.000000
# 7                36.74595                  4.0        14.500000
# 8                63.90600                 21.0         7.571429
#
#    Estimated_income_Airbnb_EUR  Holyday_rental_premium_pct
# 4                   959.655100                   47.639246
# 5                     0.000000                 -100.000000
# 6                     0.000000                 -100.000000
# 7                   569.562225                   19.907837
# 8                  1433.320286                   73.735792

# %%
fin['Holyday_rental_premium_pct'] = fin.Holyday_rental_premium_pct.replace(np.inf,0)
fin.head(15)
# Out:
#         neighborhood  rooms  Monthly_rent_Idealista_EUR  \
# 4           Abrantes      2                       650.0
# 5           Abrantes      3                       750.0
# 6           Abrantes      4                      1000.0
# 7            Acacias      0                       475.0
# 8            Acacias      1                       825.0
# 9            Acacias      2                      1012.5
# 10           Acacias      3                      1300.0
# 11           Acacias      4                      1350.0
# 12           Adelfas      1                       975.0
# 13           Adelfas      2                      1200.0
# 14           Adelfas      3                      1400.0
# 15           Adelfas      4                      1650.0
# 16        Aeropuerto      2                       650.0
# 17  Alameda de Osuna      1                       899.0
# 18  Alameda de Osuna      2                      1100.0
#
#     Number_flats_IDEALISTA  Avg_Price_Night_Airbnb  Number_flats_AIRBNB  \
# 4                      4.0                56.45030                  1.0
# 5                      3.0                 0.00000                  0.0
# 6                      4.0                 0.00000                  0.0
# 7                      1.0                36.74595                  4.0
# 8                      6.0                63.90600                 21.0
# 9                      4.0                83.61035                 18.0
# 10                    10.0                63.90600                  1.0
# 11                     1.0               117.16100                  1.0
# 12                     5.0                69.23150                 10.0
# 13                    11.0                83.07780                  9.0
# 14                    13.0               150.17910                  1.0
# 15                     1.0               106.51000                  1.0
# 16                     1.0                 0.00000                  0.0
# 17                     2.0                 0.00000                  0.0
# 18                     9.0                87.87075                  2.0
#
#     availability_30  Estimated_income_Airbnb_EUR  Holyday_rental_premium_pct
# 4         13.000000                   959.655100                   47.639246
# 5          0.000000                     0.000000                 -100.000000
# 6          0.000000                     0.000000                 -100.000000
# 7         14.500000                   569.562225                   19.907837
# 8          7.571429                  1433.320286                   73.735792
# 9          8.666667                  1783.687467                   76.166663
# 10        13.000000                  1086.402000                  -16.430615
# 11         2.000000                  3280.508000                  143.000593
# 12        11.800000                  1260.013300                   29.232133
# 13         9.111111                  1735.402933                   44.616911
# 14        10.000000                  3003.582000                  114.541571
# 15        14.000000                  1704.160000                    3.282424
# 16         0.000000                     0.000000                 -100.000000
# 17         0.000000                     0.000000                 -100.000000
# 18        10.000000                  1757.415000                   59.765000

# %% [markdown]
# ### SELECTION OF POPULAR NEIGHBOURHOODS. FINAL DATASET
# There are many areas where Airbnb listings are almost non existant.
# Figures related to areas with less than 5 listings are misleading and not reliable. We cannot get a grasp of a certain
# rental market just based on few homes listings so we get rid of these neighbourhoods.

# %%
center = fin.drop(fin[(fin.Number_flats_AIRBNB<5)].index)
center.shape
# Out:
# (161, 9)

# %%
center.to_csv('center.csv')

# %%
center.head(25)
# Out:
#       neighborhood  rooms  Monthly_rent_Idealista_EUR  Number_flats_IDEALISTA  \
# 8          Acacias      1                       825.0                     6.0
# 9          Acacias      2                      1012.5                     4.0
# 12         Adelfas      1                       975.0                     5.0
# 13         Adelfas      2                      1200.0                    11.0
# 20         Almagro      0                       900.0                     2.0
# 21         Almagro      1                      1200.0                    10.0
# 22         Almagro      2                      2350.0                    27.0
# 23         Almagro      3                      2475.0                    16.0
# 26     Almendrales      0                       660.0                     7.0
# 36        Arapiles      0                       650.0                     3.0
# 37        Arapiles      1                       950.0                    19.0
# 38        Arapiles      2                      1380.0                    21.0
# 39        Arapiles      3                      1500.0                     8.0
# 43         Aravaca      2                      1175.0                     2.0
# 49       Argüelles      0                      1050.0                     7.0
# 50       Argüelles      1                      1100.0                    23.0
# 51       Argüelles      2                      1200.0                    38.0
# 52       Argüelles      3                      1735.0                     8.0
# 62   Bellas Vistas      1                       800.0                    17.0
# 63   Bellas Vistas      2                       865.0                     1.0
# 67  Hispanoamérica      1                      1090.0                    19.0
# 68  Hispanoamérica      2                      1380.0                    23.0
# 69  Hispanoamérica      3                      1800.0                    11.0
# 72      Berruguete      1                       750.0                    14.0
# 73      Berruguete      2                      1100.0                    14.0
#
#     Avg_Price_Night_Airbnb  Number_flats_AIRBNB  availability_30  \
# 8                 63.90600                 21.0         7.571429
# 9                 83.61035                 18.0         8.666667
# 12                69.23150                 10.0        11.800000
# 13                83.07780                  9.0         9.111111
# 20                69.23150                  9.0        10.000000
# 21                80.94760                 34.0         8.911765
# 22               106.51000                 21.0         9.809524
# 23               176.80660                  5.0        12.000000
# 26                34.08320                  5.0         7.000000
# 36                53.25500                 22.0         8.227273
# 37                62.84090                 27.0         8.740741
# 38                95.85900                 12.0        10.750000
# 39               154.43950                  5.0         7.400000
# 43                76.68720                  5.0        13.600000
# 49                63.90600                 12.0         9.666667
# 50                79.88250                 44.0         8.795455
# 51                99.05430                 37.0         8.945946
# 52               164.02540                 10.0        11.900000
# 62                53.25500                 11.0        10.181818
# 63                62.30835                 14.0         8.357143
# 67                77.75230                 18.0        11.222222
# 68               100.11940                 14.0         8.285714
# 69               143.78850                  5.0        11.400000
# 72                53.25500                 13.0        11.615385
# 73                59.64560                  7.0         7.714286
#
#     Estimated_income_Airbnb_EUR  Holyday_rental_premium_pct
#
# 443        13.434783                   741.031748                   -1.195767
# 191         8.200000                  2066.507020                   -6.067863
# 356        16.666667                  1136.106667                   -7.256599
# 22          9.809524                  2150.487619                   -8.489889
# 383        20.428571                   662.644357                   -8.600778
# 152        15.833333                   844.979333                   -9.142007
# 131         9.111111                  3337.313333                  -22.388062
# 129        10.697248                  2055.936147                  -22.417504
# 290        19.500000                  1230.190500                  -27.635853
# 112        11.750000                  3518.291575                  -40.367939
# 463        20.076923                   634.144154                  -42.350531
#
# [161 rows x 9 columns]

# %%
# Neighbourhoods with highest occupancy, most demanded
center.sort_values(by='availability_30',ascending=True)
# Out:
#                     neighborhood  rooms  Monthly_rent_Idealista_EUR  \
# 506                       Atocha      1                         0.0
# 393                   San Andrés      1                       450.0
# 590                   Rios Rosas      0                         0.0
# 153                   Concepción      2                       820.0
# 182                     Delicias      3                      1450.0
# 301                     Numancia      2                       800.0
# 333              Palos de Moguer      0                       750.0
# 600                  Universidad      4                         0.0
# 400                    San Diego      2                       657.5
# 250                  Embajadores      0                       900.0
# 235                       Cortes      2                      1600.0
# 373                     Quintana      2                       750.0
# 252                  Embajadores      2                      1250.0
# 26                   Almendrales      0                       660.0
# 314                     Pacífico      3                      1400.0
# 254                  Embajadores      4                      2500.0
# 435                          Sol      0                      1100.0
# 274                  Universidad      0                       950.0
# 277                  Universidad      3                      1925.0
# 538                  Embajadores      5                         0.0
# 469                       Ventas      1                       700.0
# 255                      Legazpi      1                       875.0
# 39                      Arapiles      3                      1500.0
# 585             Puerta del Angel      1                         0.0
# 251                  Embajadores      1                       875.0
# 237                       Cortes      4                      2200.0
# 8                        Acacias      1                       825.0
# 73                    Berruguete      2                      1100.0
# 438                          Sol      3                      1700.0
# 436                          Sol      1                      1150.0
# ..                           ...    ...                         ...
# 52                     Argüelles      3                      1735.0
# 176                  Castillejos      2                      1324.5
# 23                       Almagro      3                      2475.0
# 284                   Niño Jesús      2                      1550.0
# 220                         Goya      1                      1000.0
# 595                          Sol      4                         0.0
# 376                    Recoletos      0                       850.0
# 262                        Lista      3                      2150.0
# 302                     Numancia      3                       735.0
# 135                Ciudad Jardín      2                      1250.0
# 256                      Legazpi      2                      1000.0
# 448                Valdeacederas      1                       750.0
# 445                    Trafalgar      2                      1600.0
# 355                  Prosperidad      1                      1050.0
# 443                    Trafalgar      0                       750.0
# 43                       Aravaca      2                      1175.0
# 118                     Castilla      1                      1000.0
# 175                  Castillejos      1                       950.0
# 105  Casco Histórico de Vallecas      1                       600.0
# 408                   San Isidro      3                       800.0
# 464                 Vallehermoso      2                      1600.0
# 152                   Concepción      1                       930.0
# 380                    Recoletos      4                      4000.0
# 356                  Prosperidad      2                      1225.0
# 106  Casco Histórico de Vallecas      2                       600.0
# 210             Fuente del Berro      2                      1200.0
# 449                Valdeacederas      2                       900.0
# 290                 Nueva España      2                      1700.0
# 463                 Vallehermoso      1                      1100.0
# 383                        Rejas      1                       725.0
#
#      Number_flats_IDEALISTA  Avg_Price_Night_Airbnb  Number_flats_AIRBNB  \
# 506                     0.0                57.51540                  6.0
# 274         7.127660                  1339.873138                   41.039278
# 277         7.225806                  2910.815226                   51.211181
# 538         7.285714                  4838.597143                    0.000000
# 469         7.333333                  1182.971067                   68.995867
# 255         7.400000                  1516.489380                   73.313072
# 39          7.400000                  3490.332700                  132.688847
# 585         7.421053                  1202.441842                    0.000000
# 251         7.456044                  1416.682487                   61.906570
# 237         7.545455                  3826.613818                   73.936992
# 8           7.571429                  1433.320286                   73.735792
# 73          7.714286                  1329.244800                   20.840436
# 438         7.740000                  4030.551420                  137.091260
# 436         7.742958                  1777.948178                   54.604189
# ..               ...                          ...                         ...
# 52         11.900000                  2968.859740                   71.115835
# 176        12.000000                  1533.744000                   15.797961
# 23         12.000000                  3182.518800                   28.586618
# 284        12.000000                  1917.180000                   23.689032
# 220        12.264706                  1501.744010                   50.174401
# 595        12.333333                  3951.521000                    0.000000
# 376        12.388889                  1313.031611                   54.474307
# 262        12.500000                  2413.782875                   12.268971
# 302        12.600000                  1204.628100                   63.894980
# 135        12.600000                  1853.274000                   48.261920
# 256        12.800000                  1831.972000                   83.197200
# 448        13.000000                   905.335000                   20.711333
# 445        13.090909                  1837.007018                   14.812939
# 355        13.333333                  1286.995833                   22.571032
# 443        13.434783                   741.031748                   -1.195767
# 43         13.600000                  1257.670080                    7.035751
# 118        13.888889                  1029.596667                    2.959667
# 175        14.400000                  1163.089200                   22.430442
# 105        14.625000                   802.419713                   33.736619
# 408        14.800000                  1133.266400                   41.658300
# 464        15.714286                  1978.042857                   23.627679
# 152        15.833333                   844.979333                   -9.142007
# 380        16.666667                  6646.224000                   66.155600
# 356        16.666667                  1136.106667                   -7.256599
# 106        17.200000                  1363.328000                  127.221333
# 210        17.857143                  1293.335714                    7.777976
# 449        18.000000                   990.543000                   10.060333
# 290        19.500000                  1230.190500                  -27.635853
# 463        20.076923                   634.144154                  -42.350531
# 383        20.428571                   662.644357                   -8.600778
#
# [161 rows x 9 columns]

# %%
import pandas as pd
import plotly.plotly as py

from ipywidgets import widgets 

from plotly.widgets import GraphWidget

# import data
complaints = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gantt_example.csv')

# we will define a function that will handle the input from the dropdown widget
def update_plot(complaint):
    #is_noise = complaints['Complaint Type'] == complaint['new']
    is_noise = complaints['Resource'] == complaint['new']
    temp = complaints[is_noise]
    data = temp.groupby(complaints['Borough'])['Resource'].count()
    
    x = []
    y = []
    for i in range(len(data)):
        x.append(data.index[i])
        y.append(data[i])

    graph.restyle({
                'x': [x],
                'y': [y],
            })
    graph.relayout({'title': 'Number of {} Complaints in New York by Borough'.format(complaint['new'])})

w = widgets.Dropdown(
    options= list(complaints['Resource'].unique()),
    value='A',
    description='Resource',  
)

graph = GraphWidget('https://plot.ly/~kevintest/1176/')

# observe will set a listener for activity on our dropdown menu
w.observe(update_plot, names="selected_label") 

display(w)
display(graph)
# Out:
#   File "<ipython-input-31-6e8cd3e77b7e>", line 2
#     widgets.Dropdown(
#           ^
# SyntaxError: invalid syntax

# %%
# PLot ly dropdown menus
data = [go.Bar(z=idealista.values.tolist())]
updatemenus=list([
    dict(
        buttons=list([   
            dict(
                args=['Bar', 'Bar'],
                label='neighborhood',
                method='restyle'
            ),
            dict(
                args=['Bar', 'Bar'],
                label='room',
                method='restyle'
            ),  
            dict(
                args=['Bar', 'Bar'],
                label='floor',
                method='restyle'
            ) 
        ]),
        direction = 'down',
        pad = {'r': 10, 't': 10},
        showactive = True,
        x = 0.1,
        xanchor = 'left',
        y = 1.1,
        yanchor = 'top' 
    ),
])
annotations = list([
    dict(text='Trace type:', x=0, y=1.085, yref='paper', align='left', showarrow=False)
])
layout['updatemenus'] = updatemenus
layout['annotations'] = annotations

fig = dict(data=data, layout=layout)
py.iplot(fig, filename='Price')
# Out:
# ---------------------------------------------------------------------------
# PlotlyDictKeyError                        Traceback (most recent call last)
# <ipython-input-8-4c81daef183d> in <module>()
#       1 # PLot ly dropdown menus
# ----> 2 data = [go.Bar(z=idealista.values.tolist())]
#       3 updatemenus=list([
#       4     dict(
#       5         buttons=list([
#
# /home/dsc/anaconda2/lib/python2.7/site-packages/plotly/graph_objs/graph_objs.pyc in __init__(self, *args, **kwargs)
#     375         d = {key: val for key, val in dict(*args, **kwargs).items()}
#     376         for key, val in d.items():
# --> 377             self.__setitem__(key, val, _raise=_raise)
#     378
#     379     def __dir__(self):
#
# /home/dsc/anaconda2/lib/python2.7/site-packages/plotly/graph_objs/graph_objs.pyc in __setitem__(self, key, value, _raise)
#     426                 if _raise:
#     427                     path = self._get_path() + (key, )
# --> 428                     raise exceptions.PlotlyDictKeyError(self, path)
#     429                 return
#     430
#
# PlotlyDictKeyError: 'z' is not allowed in 'bar'
#
# Path To Error: ['z']
#
# Valid attributes for 'bar' at path [] under parents []:
#
#     ['bardir', 'base', 'basesrc', 'constraintext', 'customdata',
#     'customdatasrc', 'dx', 'dy', 'error_x', 'error_y', 'hoverinfo',
#     'hoverinfosrc', 'hoverlabel', 'hovertext', 'hovertextsrc', 'ids',
#     'idssrc', 'insidetextfont', 'legendgroup', 'marker', 'name', 'offset',
#     'offsetsrc', 'opacity', 'orientation', 'outsidetextfont', 'r', 'rsrc',
#     'showlegend', 'stream', 't', 'text', 'textfont', 'textposition',
#     'textpositionsrc', 'textsrc', 'tsrc', 'type', 'uid', 'visible',
#     'width', 'widthsrc', 'x', 'x0', 'xaxis', 'xcalendar', 'xsrc', 'y',
#     'y0', 'yaxis', 'ycalendar', 'ysrc']
#
# Run `<bar-object>.help('attribute')` on any of the above.
# '<bar-object>' is the object at []

# %%
complaints = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gantt_example.csv')

# we will define a function that will handle the input from the dropdown widget
def update_plot(complaint):
    #is_noise = complaints['Complaint Type'] == complaint['new']
    is_noise = complaints['Resource'] == complaint['new']
    temp = complaints[is_noise]
    data = temp.groupby(complaints['Borough'])['Resource'].count()
    
    x = []
    y = []
    for i in range(len(data)):
        x.append(data.index[i])
        y.append(data[i])

# %%
complaints.head()
# Out:
#     Task                Start               Finish  Complete Resource
# 0  Job A           2009-01-01           2009-02-26        23        A
# 1  Job B           2009-03-05           2009-04-15        55        A
# 2  Job C  2009-02-20 12:40:00  2009-05-30 15:12:44        97        C
# 3  Job D           2009-03-10           2009-04-30        11        B
# 4  Job E           2009-02-25           2009-06-30        14        A
