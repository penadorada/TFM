# %% [markdown]
# ![](https://s14-eu5.ixquick.com/cgi-bin/serveimage?url=https%3A%2F%2Fpythonprogramming.net%2Fstatic%2Fimages%2Fcategories%2Fmachine-learning-playlist.png&sp=42e9f77a3ce871e8bbef1abd43e89ab6)
# # Dataset for model implementation
#
# The purpose of this notebook is to create a dataset ready to be implemented in R for machine learning algorithms.
# #### - Data Cleaning
# #### - Variable selection for model

# %%
import pandas as pd
import numpy as np

# %%
aibb = pd.read_csv('airbnb.csv')# file saved in Notebook FIRST_DATA_FILTERING
aibb.shape
# Out:
# (10077, 98)

# %% [markdown]
# ### ROOM TYPE SELECTION.
#
# The goal of the project is to build a decision tool for landlors in order to maximize real state income.
#
# Airbnb  offers three types of accomodation:
#
# - Entire Homes or Apartments.
# - Rooms.
# - Shared rooms.
#
# Shared rooms are less than 200 records and out of interest for the scope of this project. It is not considered as an
# "asset" and therefore it will not be taken into account in the analysis.

# %%
# Shared room category removed
aibb = aibb.drop(aibb[aibb.room_type=='Shared room'].index)
aibb.shape
# Out:
# (9916, 98)

# %% [markdown]
# ### DATA CLEANING

# %% [markdown]
# CANCELATION POLICY.
#
# In order to ease calculations (it will be a dummy variable) Super_strict_30 and 60 are reclassified  as strict.

# %%
# CANCELATION POLICY
 
aibb.cancellation_policy.value_counts()
# Out:
# strict             3879
# moderate           3145
# flexible           2888
# super_strict_30       2
# super_strict_60       2
# Name: cancellation_policy, dtype: int64

# %%
aibb['cancellation_policy'] = aibb.cancellation_policy.astype(str)
aibb['cancellation_policy']= aibb.cancellation_policy.str.replace('super_strict_30','strict')
aibb['cancellation_policy']= aibb.cancellation_policy.str.replace('super_strict_60','strict')

# %%
aibb.cancellation_policy.value_counts()
# Out:
# strict      3883
# moderate    3145
# flexible    2888
# Name: cancellation_policy, dtype: int64

# %% [markdown]
# ZIPCODE.
#
# Amend wrong values (input mistakes)

# %%
# ZIPCODE
aibb.zipcode.value_counts()
# Out:
# 28012           1580
# 28004           1383
# 28005            918
# 28013            779
# 28014            528
# 28015            422
# 28045            350
# 28010            288
# 28008            218
# 28001            187
# 28028            185
# 28011            182
# 28009            161
# 28019            156
# 28006            152
# 28007            148
# 28020            142
# 28003            126
# 28039            112
# 28002            106
# 28027             89
# 28017             88
# 28025             87
# 28043             81
# 28029             80
# 28033             72
# 28042             69
# 28026             67
# 28053             60
# 28038             54
#                 ...
# 28040             10
# 28054             10
# 28830              2
# 28224              1
# 28730              1
# 08015              1
# 28105              1
# 28058              1
# 28052              1
# 28056              1
#                    1
# 10100              1
# 28290              1
# 28060              1
# 2804               1
# 29012              1
# 28660              1
# 28002\n28002       1
# 84084              1
# 27004              1
# 280013             1
# 28049              1
# 28048              1
# 28051\n28051       1
# 2015               1
# 27013              1
# 28094              1
# 2815               1
# 2802\n28012        1
# 28850              1
# Name: zipcode, dtype: int64

# %%
# Correction of wrong values
aibb['zipcode'] = aibb.zipcode.replace('2802\n28012',28012)
aibb['zipcode'] = aibb.zipcode.replace('28051\n28051',28051)
aibb['zipcode'] = aibb.zipcode.replace('28002\n28002',28002)

# %%
# remove space from room type name so that R can perform Linear regression
aibb['room_type'] =aibb.room_type.str.replace('Entire home/apt','Entire_home/apt')
aibb.room_type.value_counts()
# Out:
# Entire_home/apt    6271
# Private room       3645
# Name: room_type, dtype: int64

# %% [markdown]
# ## Missing Values. NANs
#
# Some Machine Learning  algorithms are not configured to cope with NaNs, and may crash if they encounter a missing value.
# Provided that many columns have multiple NANs and we cannot delete them (removal of those observations may affect final results) we will replace them with the average value of the feature or with 0.

# %%
aibb['bathrooms'] = aibb.bathrooms.replace(np.nan,1.23)
aibb['bedrooms'] = aibb.bedrooms.replace(np.nan,1.31)
aibb['beds'] = aibb.beds.replace(np.nan,2.03)
aibb['security_deposit'] = aibb.security_deposit.replace(np.nan,0) # NaN implies no deposit required so replaced by 0.
aibb['reviews_per_month'] = aibb.reviews_per_month.replace(np.nan,0)
aibb['review_scores_value'] = aibb.review_scores_value.replace(np.nan,0)
aibb['review_scores_accuracy'] = aibb.review_scores_accuracy.replace(np.nan,0)
aibb['review_scores_rating'] = aibb.review_scores_rating.replace(np.nan,0)
aibb['cleaning_fee'] = aibb.cleaning_fee.replace(np.nan,0)

# %% [markdown]
# ### VARIABLE SELECTION FOR ML MODEL
#
# Explore all columns to find features that may improve model accuracy.

# %%
pd.set_option('display.max_columns',None)
aibb.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1       id                           listing_url  \
# 0           0             0  7830063  https://www.airbnb.com/rooms/7830063
# 1           1             1  9898596  https://www.airbnb.com/rooms/9898596
#
#         scrape_id last_scraped                                     name  \
# 0  20170407214119   2017-04-08                Quiet room in Plaza Mayor
# 1  20170407214119   2017-04-08  Homely apartment in the heart of Madrid
#
#                                              summary  \
# 0  Room in magnificent property in the historic c...
# 1  Spacious apartment for up to 10 people, with a...
#
#                                                space  \
# 0  Based in the historic center of Madrid, to 1 m...
# 1  This spacious apartment is located in the cent...
#
#                                          description experiences_offered  \
# 0  Room in magnificent property in the historic c...                none
# 1  Spacious apartment for up to 10 people, with a...                none
#
#                                neighborhood_overview  \
# 0  In the historic heart of Madrid, near the Plaz...
# 1  The Living Santa Ana Apartments are located in...
#
#                                                notes  \
# 0  Check-in from 21:00 to 23:00 has an extra char...
# 1                                                NaN
#
#                                              transit  \
# 0  Very well connected by buses and subwa (Tirso ...
# 1          We are 3m walk from the La Latina subway.
#
#                                               access  \
# 0  Quiet room on the first floor of historic buil...
# 1                                                NaN
#
#                                          interaction  \
# 0  Maps and all kind of information and recommend...
# 1  During his stay, please contact us if you have...
#
#                                          house_rules  \
# 0  Please respect the silence of the other guests...
# 1  The apartment is located in a community of nei...
#
#                                        thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/99669989/f...
# 1  https://a0.muscache.com/im/pictures/f3336e14-5...
#
#                                           medium_url  \
# 0  https://a0.muscache.com/im/pictures/99669989/f...
# 1  https://a0.muscache.com/im/pictures/f3336e14-5...
#
#                                          picture_url  \
# 0  https://a0.muscache.com/im/pictures/99669989/f...
# 1  https://a0.muscache.com/im/pictures/f3336e14-5...
#
#                                       xl_picture_url   host_id  \
# 0  https://a0.muscache.com/im/pictures/99669989/f...  41032693
# 1  https://a0.muscache.com/im/pictures/f3336e14-5...  50908516
#
#                                      host_url    host_name  host_since  \
# 0  https://www.airbnb.com/users/show/41032693  Bluekitchen  2015-08-10
# 1  https://www.airbnb.com/users/show/50908516       Daniel  2015-12-09
#
#                         host_location  \
# 0  Madrid, Community of Madrid, Spain
# 1  Madrid, Community of Madrid, Spain
#
#                                           host_about host_response_time  \
# 0  Somos dos amigos de la infancia de Madrid que ...     within an hour
# 1  Somos Amanda y Dani, tenemos este establecimie...     within an hour
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0               100%                   NaN                 f
# 1               100%                   NaN                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/41032693/prof...
# 1  https://a0.muscache.com/im/pictures/0061d173-a...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/41032693/prof...          La Latina
# 1  https://a0.muscache.com/im/pictures/0061d173-a...          La Latina
#
#    host_listings_count  host_total_listings_count  \
# 0                  7.0                        7.0
# 1                  1.0                        1.0
#
#                        host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio']                    t
# 1  ['email', 'phone', 'reviews', 'jumio']                    t
#
#   host_identity_verified                                             street  \
# 0                      t  La Latina, Madrid, Comunidad de Madrid 28005, ...
# 1                      t  La Latina, Madrid, Comunidad de Madrid 28005, ...
#
#   neighbourhood neighbourhood_cleansed neighbourhood_group_cleansed    city  \
# 0     La Latina                Palacio                       Centro  Madrid
# 1     La Latina                Palacio                       Centro  Madrid
#
#                  state zipcode  market smart_location country_code country  \
# 0  Comunidad de Madrid   28005  Madrid  Madrid, Spain           ES   Spain
# 1  Comunidad de Madrid   28005  Madrid  Madrid, Spain           ES   Spain
#
#     latitude  longitude is_location_exact property_type        room_type  \
# 0  40.412275  -3.708718                 t         House     Private room
# 1  40.411093  -3.708985                 t     Apartment  Entire_home/apt
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0             2        2.0       1.0   2.0  Real Bed
# 1            10        1.0       3.0   9.0  Real Bed
#
#                                            amenities  square_feet     price  \
# 0  {TV,Internet,"Wireless Internet",Kitchen,Doorm...          NaN   44.7342
# 1  {TV,Internet,"Wireless Internet","Wheelchair a...          NaN  143.7885
#
#    weekly_price monthly_price  security_deposit  cleaning_fee  \
# 0    281.663694     $1,200.00         93.887898     14.083185
# 1           NaN           NaN        187.775796     37.555159
#
#    guests_included extra_people  minimum_nights  maximum_nights  \
# 0                2        $0.00               2              30
# 1                6       $15.00               1            1125
#
#   calendar_updated  has_availability  availability_30  availability_60  \
# 0      2 weeks ago               NaN                4               13
# 1            today               NaN                0                5
#
#    availability_90  availability_365 calendar_last_scraped  number_of_reviews  \
# 0               37               165            2017-04-08                100
# 1               14               230            2017-04-08                 68
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2015-08-23  2017-04-02                  92.0                     9.0
# 1   2015-12-31  2017-04-04                  93.0                     9.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        9.0                   10.0
# 1                        9.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                  9.0
# 1                         10.0                    10.0                  9.0
#
#   requires_license license  jurisdiction_names instant_bookable  \
# 0                t     NaN                 NaN                t
# 1                t     NaN                 NaN                t
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
#
#   require_guest_phone_verification  calculated_host_listings_count  \
# 0                                f                               7
# 1                                f                               1
#
#    reviews_per_month  Price_Person_Night
# 0               5.04            22.36710
# 1               4.39            23.96475

# %%
# Features selected for ML model:
aibb = aibb[['neighbourhood_group_cleansed','availability_30','is_location_exact','host_identity_verified',
              'bathrooms','bedrooms','beds','minimum_nights','maximum_nights','price','Price_Person_Night',
              'room_type','security_deposit','cleaning_fee','number_of_reviews','cancellation_policy','reviews_per_month','review_scores_rating',
               'review_scores_accuracy','review_scores_value','extra_people','guests_included','accommodates','host_is_superhost',
              'instant_bookable']]

# %%
aibb.head()
# Out:
#   neighbourhood_group_cleansed  availability_30 is_location_exact  \
# 0                       Centro                4                 t
# 1                       Centro                0                 t
# 2                       Centro                4                 t
# 3                       Centro                1                 f
# 4                       Centro                7                 t
#
#   host_identity_verified  bathrooms  bedrooms  beds  minimum_nights  \
# 0                      t        2.0       1.0   2.0               2
# 1                      t        1.0       3.0   9.0               1
# 2                      f        1.0       1.0   1.0               1
# 3                      f        1.0       1.0   1.0               3
# 4                      t        1.5       2.0   2.0               1
#
#    maximum_nights     price  Price_Person_Night        room_type  \
# 0              30   44.7342            22.36710     Private room
# 1            1125  143.7885            23.96475  Entire_home/apt
# 2            1125   86.2731            43.13655  Entire_home/apt
# 3            1125   45.7993            45.79930     Private room
# 4            1125   53.2550            26.62750  Entire_home/apt
#
#    security_deposit  cleaning_fee  number_of_reviews cancellation_policy  \
# 0         93.887898     14.083185                100            moderate
# 1        187.775796     37.555159                 68            moderate
# 2          0.000000     14.083185                 34              strict
# 3          0.000000      0.000000                 11              strict
# 4        234.719745     18.777580                  6              strict
#
#    reviews_per_month  review_scores_rating  review_scores_accuracy  \
# 0               5.04                  92.0                     9.0
# 1               4.39                  93.0                     9.0
# 2               5.57                  93.0                     9.0
# 3               0.24                  98.0                    10.0
# 4               4.29                 100.0                    10.0
#
#    review_scores_value extra_people  guests_included  accommodates  \
# 0                  9.0        $0.00                2             2
# 1                  9.0       $15.00                6            10
# 2                  9.0       $10.00                2             2
# 3                 10.0       $10.00                1             2
# 4                 10.0       $25.00                2             4
#
#   host_is_superhost instant_bookable
# 0                 f                t
# 1                 f                t
# 2                 t                t
# 3                 t                f
# 4                 f                f

# %%
aibb.describe()
# Out:
#        availability_30    bathrooms     bedrooms         beds  minimum_nights  \
# count      9916.000000  9916.000000  9916.000000  9916.000000     9916.000000
# mean         11.393304     1.233252     1.310365     2.033092        2.552945
# std           8.672236     0.546748     0.855380     1.516631        8.376643
# min           0.000000     0.000000     0.000000     1.000000        1.000000
# 25%           5.000000     1.000000     1.000000     1.000000        1.000000
# 50%           9.000000     1.000000     1.000000     2.000000        2.000000
# 75%          16.000000     1.000000     2.000000     2.000000        3.000000
# max          30.000000     8.000000    10.000000    16.000000      365.000000
#
#        maximum_nights        price  Price_Person_Night  security_deposit  \
# count     9916.000000  9916.000000         9916.000000       9916.000000
# mean       980.922852    74.414786           52.731062         81.367555
# std      10249.174631    64.100485           54.054596        149.696621
# min          1.000000     9.585900            1.633153          0.000000
# 25%        360.000000    37.278500           26.627500          0.000000
# 50%       1125.000000    60.710700           37.278500          0.000000
# 75%       1125.000000    90.533500           58.580500        140.831847
# max    1000000.000000  1065.100000          905.335000       4491.597033
#
#        cleaning_fee  number_of_reviews  reviews_per_month  \
# count   9916.000000        9916.000000        9916.000000
# mean      17.175160          28.634933           1.848756
# std       21.273206          42.466663           1.959162
# min        0.000000           0.000000           0.000000
# 25%        0.000000           2.000000           0.280000
# 50%       14.083185          12.000000           1.200000
# 75%       28.166369          37.000000           2.910000
# max      469.439489         446.000000          17.210000
#
#        review_scores_rating  review_scores_accuracy  review_scores_value  \
# count           9916.000000             9916.000000          9916.000000
# mean              76.257765                7.822610             7.654397
# std               35.230043                3.627054             3.572329
# min                0.000000                0.000000             0.000000
# 25%               80.000000                8.000000             8.000000
# 50%               92.000000                9.000000             9.000000
# 75%               97.000000               10.000000            10.000000
# max              100.000000               10.000000            10.000000
#
#        guests_included  accommodates
# count      9916.000000   9916.000000
# mean          1.653893      3.326039
# std           1.147874      2.023835
# min           1.000000      1.000000
# 25%           1.000000      2.000000
# 50%           1.000000      3.000000
# 75%           2.000000      4.000000
# max          16.000000     16.000000

# %%
aibb.isnull().sum()
# Out:
# neighbourhood_group_cleansed    0
# availability_30                 0
# is_location_exact               0
# host_identity_verified          0
# bathrooms                       0
# bedrooms                        0
# beds                            0
# minimum_nights                  0
# maximum_nights                  0
# price                           0
# Price_Person_Night              0
# room_type                       0
# security_deposit                0
# cleaning_fee                    0
# number_of_reviews               0
# cancellation_policy             0
# reviews_per_month               0
# review_scores_rating            0
# review_scores_accuracy          0
# review_scores_value             0
# extra_people                    0
# guests_included                 0
# accommodates                    0
# host_is_superhost               0
# instant_bookable                0
# dtype: int64

# %% [markdown]
# ### Final File for Linear Regression analysis  and Machine Learning in R

# %%
# Saved in Dataset folder
aibb.to_csv('RLM.csv')
